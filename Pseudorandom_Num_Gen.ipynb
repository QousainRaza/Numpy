# %% [markdown]
# # Pseudorandom Number Generation

# %%
import numpy as np

# %%
sample = np.random.standard_normal(size = (4,4))
sample
# Out:
# array([[ 1.10428327,  1.86060782, -0.19657724, -0.47312699],
#        [ 0.94010973,  0.25270149,  1.11426337, -0.93983092],
#        [-1.52280473, -0.72283367, -0.56344918,  0.09405774],
#        [-1.02418692, -2.31975108,  0.61217292,  0.5497636 ]])

# %%
from random import normalvariate

# %%
N = 1_000_000

# %%
# %timeit  sample = [normalvariate(0,1) for _ in range(N)]
# Out:
# 361 ms ± 8.38 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
rng = np.random.default_rng(seed= 12345)
data = rng.standard_normal((2,3))

data
rng
# Out:
# Generator(PCG64) at 0x10683DC40
